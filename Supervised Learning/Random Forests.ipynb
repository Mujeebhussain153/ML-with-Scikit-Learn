# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
X, y = make_moons(n_samples=1000, noise=0.25, random_state=42)
plt.figure(figsize=(5,4))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, edgecolor='k')
plt.title("Make Moons Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# N Estimators's value here represent how many trees are being used 
forest = RandomForestClassifier(n_estimators=50, random_state=1)
forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.94

# %%
import pandas as pd

fi = pd.Series(forest.feature_importances_, index=["Feature 1", "Feature 2"])
fi.plot(kind='bar', color='teal', title='Feature Importances
