# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
import lightgbm as lbg

# %%
X, y = make_moons(n_samples=1000, noise=0.25, random_state=42)
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.coolwarm, edgecolor='k')
plt.title("Make Moons Data Set")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
gbm = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbm.fit(X_train, y_train)
y_pred_gb = gbm.predict(X_test)
acc = accuracy_score(y_test, y_pred_gb)
acc
# Out:
# 0.9533333333333334

# %%
# training the model using Lightgbm
# It's a powerful library where Gradient Boosting is used and it is extremely fast and memory efficient
lg = lbg.GBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 # training the model using Lightgbm
#       2 # It's a powerful library where Gradient Boosting is used and it is extremely fast and memory efficient
# ----> 3 lg = lbg.GBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
#
# AttributeError: module 'lightgbm' has no attribute 'GBMClassifier'
